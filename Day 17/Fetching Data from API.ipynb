# %%
import pandas as pd
import requests

# %%
url = "https://real-time-amazon-data.p.rapidapi.com/search"

querystring = {"query":"Phone","page":"1","country":"US","sort_by":"RELEVANCE","product_condition":"ALL","is_prime":"false","deals_and_discounts":"NONE"}

headers = {
	"x-rapidapi-key": "f25a0db5b5msh4ce9056bd0153d4p14389djsn15111efb3a4b",
	"x-rapidapi-host": "real-time-amazon-data.p.rapidapi.com",
	"Content-Type": "application/json"
}

response = requests.get(url, headers=headers, params=querystring)

# %%
df = pd.DataFrame(response.json()['data']['products'])

# %%
df
# Out:
#           asin                                      product_title  \
# 0   B0G4SW3XXP  Samsung Galaxy S26 Ultra, Unlocked Android Sma...
# 1   B0DM1S54MZ  Samsung Galaxy A16 4G LTE (128GB + 4GB) Intern...
# 2   B0FXY18C1J  Samsung Galaxy A17 5G Smart Phone, 128GB, Larg...
# 3   B0FG1THCD7  Samsung Galaxy S25 FE Cell Phone (2025), 256GB...
# 4   B0DSWT17NG  Samsung Galaxy A06 4G LTE (64GB + 4GB) Latin V...
# 5   B0FXY1DZ78  Samsung Galaxy A17 5G Smart Phone, 128GB, Larg...
# 6   B0CP6DDN1H  Motorola Moto G Play | 2024 | Unlocked | Made ...
# 7   B0DNRFGBQ4  SAMSUNG Galaxy A16 4G Dual SIM (128GB, 2025) 6...
# 8   B0BN72FYFG  Apple iPhone 14, 128GB, Midnight - Unlocked (R...
# 9   B0FTG3Z4YT  Tracfone Motorola Moto g Play 2024 [Activation...
# 10  B0CT6BQV81  Moto G Power 5G | 2024 | Unlocked | Made for U...
# 11  B09LNP1ZHT  Apple iPhone 13, 128GB, Pink - Unlocked (Renewed)
# 12  B00FRSYS12  VTech CS6719-2 2-Handset Cordless Phone with C...
# ...

# %%
df.to_csv('products.csv')
